# %%
print("Hello, World")
# Out:
# Hello, World

# %%
import numpy as np
import pandas as pd

print("NumPy :", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy : 2.5.1
# Pandas: 3.0.5
